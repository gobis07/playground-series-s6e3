# %%
import pandas as pd
# Out:
# Échec du démarrage du Kernel.
#
# Impossible de démarrer le noyau « base (Python 3.13.9) » en raison d’un délai d’attente d’utilisation des ports.
#
# Pour plus d’informations, consultez Jupyter <a href='command:jupyter.viewOutput'>log</a>.

# %%
train_data = pd.read_csv('train.csv')
test_data = pd.read_csv('test.csv')
